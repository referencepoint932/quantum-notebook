# %% [markdown]
# # 🔬 Quantum Interference with Deutsch Algorithm Variations

# %% [markdown]
# ## Introduction
#
# todo

# %% [markdown]
# ### Sub
#
# todo

# %% [markdown]
# ### Setup & imports
#
# We use **Qiskit** with its built‑in `BasicSimulator`.

# %%
import matplotlib.pyplot as plt
import random
from qiskit import QuantumCircuit, transpile
from qiskit.providers.basic_provider import BasicSimulator
from qiskit.quantum_info import Statevector
from qiskit.visualization.bloch import Bloch
from qiskit.visualization import plot_bloch_multivector

# %% [markdown]
# ### Deutsh Algorithm
#
# We can use states in perfect superposition to create **interference** patterns.  For example, the Deutsch algorithm uses a single qubit to determine if a function is constant or balanced.  A constant function (f(0) = f(1)) creates constructive interference, while a balanced function (f(0) ≠ f(1)) creates destructive interference.
#
# | function | f(0) | f(1) |  class
# |:--------:|:----:|:----:|:--------:|
# |    f1    |  0   |  0   | constant |
# |    f2    |  1   |  1   | constant |
# |    f3    |  0   |  1   | balanced |
# |    f4    |  1   |  0   | balanced |

# %%
# demo
# Out:
#   Cell In[4], line 1
#     def constant(x)
#                    ^
# SyntaxError: expected ':'
